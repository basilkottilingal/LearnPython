# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
XP,YP,ZP = [0.750000, 0.500000, 0.500000];
xlim = [XP-0.3/32.,XP+0.3/32.]
ylim = [YP-0.3/32.,YP+0.3/32.]
zlim = [ZP-0.3/32.,ZP+0.3/32.]

# %%
f = open('elements.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))


# %matplotlib notebook

ax = plt.gca(projection="3d")


# ax.add_collection(Poly3DCollection(triangles))

for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'm')

ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')

    


ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

ax = plt.gca(projection="3d")

f = open('elements.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'm')

f = open('contour.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'g', normalize=False)
    
f = open('contournormal.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'r', normalize=False)
    
f = open('normal.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=10., color = 'b', normalize=False)
f = open('normal2.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=10., color = 'c', normalize=False)


ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#vertex types.

f = open('edgesall.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))

f = open('vertextype.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
lll, = np.shape(data);
ppp = (int) (lll/4);
points = np.reshape(data, (ppp,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

for i in range(p):
    edge = np.copy(edges[i]);
    ax.plot(edge[0], edge[1], edge[2], color = 'y', linewidth = .2)

ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')
 

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(ppp):
    point = points[i]
    c = int (np.floor(point[3]))
    ax.scatter(point[0],point[1], point[2], color = colors[c], linewidth = 2., marker='o')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-fe6807cced5a> in <module>
#       1 #vertex types.
#       2
# ----> 3 f = open('edgesall.dat', 'r')
#       4 data = np.genfromtxt(f, delimiter=',')
#       5 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'edgesall.dat'

# %%
#edgetype from vertextype
#Bounding polygon using edgetypes.

f = open('edgetype.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

f = open('vertextype.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
lll, = np.shape(data);
ppp = (int) (lll/4);
points = np.reshape(data, (ppp,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)

ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')
 


for i in range(ppp):
    point = points[i]
    c = int (np.floor(point[3]))
    ax.scatter(point[0],point[1], point[2], color = colors[c], linewidth = 2., marker='o')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()     

np.shape(edges)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (17, 7)

# %%
#bounding polygon and projection
f = open('projection.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))

f = open('boundary.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
ll, = np.shape(data);
pp = (int) (ll/6); q = 3 ; r =2;
edgesp = np.reshape(data, (pp,q,r))

f = open('projection2.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
lll, = np.shape(data);
ppp = (int) (lll/6); q = 3 ; r =2;
edgese = np.reshape(data, (ppp,q,r))


# %matplotlib notebook

ax = plt.gca(projection="3d")


for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'g', normalize=False)
for i in range(pp):
    edge = np.copy(edgesp[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'r', normalize=False)
for i in range(ppp):
    edge = np.copy(edgese[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'b', normalize=False)

    
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#bounding polygon and projection
# %matplotlib notebook

ax = plt.gca(projection="3d")

f = open('projection.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'g', normalize=False)

f = open('projection2.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'r', normalize=False)
    
f = open('boundary.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'b', normalize=False)

f = open('heightp.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'c', normalize=False, linewidth = 0.5)

f = open('normalp.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'm', normalize=False, linewidth = 0.5)
    
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#bounding polygon and projection
# %matplotlib notebook

ax = plt.gca(projection="3d")

f = open('projection.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'g', normalize=False)

f = open('projection2.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'r', normalize=False)
    
f = open('boundary.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'b', normalize=False)

f = open('heighte.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'c', normalize=False, linewidth = 0.5)

f = open('normale.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'm', normalize=False, linewidth = 0.5)
    
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('boundary.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
# %matplotlib notebook

ax = plt.gca(projection="3d")

# ax.add_collection(Poly3DCollection(triangles))

for i in range(p):
    ax.plot(edges[i][0], edges[i][1], edges[i][2])
    
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('projection.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))

# %matplotlib notebook

ax = plt.gca(projection="3d")


# ax.add_collection(Poly3DCollection(triangles))

for i in range(p):
    ax.plot(edges[i][0], edges[i][1], edges[i][2])
    
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
