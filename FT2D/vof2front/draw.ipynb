# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
I_ = 22; J_ =22; K_=22;

def bounding_box():
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    
def draw_axi():
    ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
    ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
    ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')

# %%
f = open('front.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('polygons.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c/8)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('sharededges.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('shrinked.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('shrinked.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.quiver(xa,ya,za, xb-xa, yb-ya, zc-za, colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('zorder.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
f = open('cyclic.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)
    
f = open('shrinked.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))
colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.quiver(xa,ya,za, xb-xa, yb-ya, zc-za, colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
f = open('cyclic.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)
    
f = open('shrinked.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))
colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.quiver(xa,ya,za, xb-xa, yb-ya, zc-za, colors[c], linewidth = 1.)

f = open('missingpatches_continuous.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))
colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], 'm', linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
f = open('cyclic.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], 'r', linewidth = 1.)
    
colors = ['r','b','g','m','c','y','g','k','r'] 
f = open('front.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], 'b', linewidth = 1.)

xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('missingpatches.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)


xlim = [0,1.]
ylim = [0,1.]
zlim = [0,1.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
