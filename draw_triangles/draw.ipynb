# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
f = open('triangles.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/9); q = 3 ; r =3;
triangles = np.reshape(data, (p,q,r))

# %%
#interactive  (To rotate and zoom plot use following command)
# %matplotlib notebook

ax = plt.gca(projection="3d")

ax.add_collection(Poly3DCollection(triangles))

ax.set_xlim([0.6,0.8])
ax.set_ylim([0.6,0.8])
ax.set_zlim([0.6,0.8])

plt.show()
# Out:
# <img src="data:," width="0">

# %%
f = open('trianglesijk.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/9); q = 3 ; r =3;
triangles = np.reshape(data, (p,q,r))
# %matplotlib notebook

ax = plt.gca(projection="3d")

ax.add_collection(Poly3DCollection(triangles))

ax.plot([0.625, 0.65],[0.625, 0.625],[0.625, 0.625])
ax.plot([0.625, 0.625],[0.625, 0.65],[0.625, 0.625])
ax.plot([0.625, 0.625],[0.625, 0.625],[0.625, 0.65])

ax.set_xlim([0.625, 0.65625])
ax.set_ylim([0.625, 0.65625])
ax.set_zlim([0.625, 0.65625])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('trianglesijk2.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/9); q = 3 ; r =3;
triangles = np.reshape(data, (p,q,r))
# %matplotlib notebook

ax = plt.gca(projection="3d")

ax.add_collection(Poly3DCollection(triangles))

ax.plot([0.34375, 0.36],[0.34375, 0.34375],[0.34375, 0.34375])
ax.plot([0.34375, 0.34375],[0.34375, 0.36],[0.34375, 0.34375])
ax.plot([0.34375, 0.34375],[0.34375, 0.34375],[0.34375, 0.36])

ax.set_xlim([0.34375, 0.375])
ax.set_ylim([0.34375, 0.375])
ax.set_zlim([0.34375, 0.375])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('trianglesijk2.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/9); q = 3 ; r =3;
triangles = np.reshape(data, (p,q,r))
# %matplotlib notebook

ax = plt.gca(projection="3d")

ax.add_collection(Poly3DCollection(triangles))

ax.plot([0.34375, 0.36],[0.34375, 0.34375],[0.34375, 0.34375])
ax.plot([0.34375, 0.34375],[0.34375, 0.36],[0.34375, 0.34375])
ax.plot([0.34375, 0.34375],[0.34375, 0.34375],[0.34375, 0.36])

ax.set_xlim([0.34375, 0.375])
ax.set_ylim([0.34375, 0.375])
ax.set_zlim([0.34375, 0.375])

plt.show()               

#Can see the source of BUG. In this case ..
#.. collection of facets in a CV intersects all the 6 faces of cubic CV. ..
#.. When you project the facets in the direction of integration, it divides the plane of projection into 3 zones. 
#.. (a))projected region (b,c) area to either sides of projected area..
#..
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('boundaryall.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
# %matplotlib notebook

ax = plt.gca(projection="3d")

# ax.add_collection(Poly3DCollection(triangles))

for i in range(p):
    ax.plot(edges[i][0], edges[i][1], edges[i][2])

ax.set_xlim([0.625, 0.65625])
ax.set_ylim([0.625, 0.65625])
ax.set_zlim([0.625, 0.65625])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('boundary.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
# %matplotlib notebook

ax = plt.gca(projection="3d")

# ax.add_collection(Poly3DCollection(triangles))

for i in range(p):
    ax.plot(edges[i][0], edges[i][1], edges[i][2])

ax.set_xlim([0.625, 0.65625])
ax.set_ylim([0.625, 0.65625])
ax.set_zlim([0.625, 0.65625])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
