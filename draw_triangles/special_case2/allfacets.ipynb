# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
from itertools import chain

# %%
I_ = 18; J_ =18; K_=18;

def bounding_box():
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-1)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-2)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-2)/32.,(J_-1)/32.], [(K_-1)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-1)/32.,(I_-1)/32.], [(J_-2)/32.,(J_-2)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    ax.plot([(I_-2)/32.,(I_-2)/32.], [(J_-1)/32.,(J_-1)/32.], [(K_-2)/32.,(K_-1)/32.], color = 'c')
    
def draw_axi():
    ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0.2/32, 0., 0., color = 'r')
    ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0.2/32, 0., color = 'g')
    ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 0.2/32, color = 'b')

# %%
# %matplotlib notebook

ax = plt.gca(projection="3d")

# ax.add_collection(Poly3DCollection(triangles))


f = open('vofedges.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'm')
f = open('voffacets.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/9); q = 3 ; r =3;
triangles = np.reshape(data, (p,q,r))
ax.add_collection(Poly3DCollection(triangles))


# bounding_box()
# draw_axi()

# xlim = [(I_-2)/32.,(I_-1)/32.]
# ylim = [(J_-2)/32.,(J_-1)/32.]
# zlim = [(K_-2)/32.,(K_-1)/32.]
# ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

#ax = plt.gca(projection="3d")

f = open('triangles.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/9); q = 3 ; r =3;
triangles = np.reshape(data, (p,q,r))
# ax.add_collection(Poly3DCollection(triangles))

# Convert the list of triangles into a "flat" list of points
tri_points = list(chain.from_iterable(triangles))
# Get the X, Y and Z coordinates of each point
x, y, z = zip(*tri_points)
# Make list of triangle indices ([(0, 1, 2), (3, 4, 5), ...])
tri_idx = [(3 * i, 3 * i + 1, 3 * i + 2) for i in range(len(triangles))]
# Make 3D axes
ax = plt.figure().gca(projection='3d')
# Plot triangles
ax.plot_trisurf(x, y, z, triangles=tri_idx, linewidth=0, antialiased=False, shade=True)

f = open('vofedges.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'm')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

mpl.rcParams['legend.fontsize'] = 10
ax = plt.gca(projection="3d")

f = open('vofedges.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'b', linewidth=1)
# f = open('vofedges_f0.dat', 'r')
# data = np.genfromtxt(f, delimiter=',')
# f.close()
# l, = np.shape(data);
# p = (int) (l/6); q = 3 ; r =2;
# edges = np.reshape(data, (p,q,r))
# for i in range(p):
#     edge = np.copy(edges[i]);
#     x,u = np.copy(edge[0])
#     y,v = np.copy(edge[1])
#     z,w = np.copy(edge[2])
#     ax.plot(edge[0], edge[1], edge[2], color = 'g', linewidth=1)
f = open('alledges.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'r', linewidth=0.1)
    
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 2/32, 0., 0., color = 'r', label = 'Front Triangluar Facets')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 2/32, 0., color = 'g')
ax.quiver((I_-2)/32., (J_-2)/32., (K_-2)/32., 0., 0., 2/32, color = 'b', label = 'F2V3D vof facets')
ax.legend()

    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('edgesall.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))


# %matplotlib notebook

ax = plt.gca(projection="3d")


# ax.add_collection(Poly3DCollection(triangles))

for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, normalize=False)


bounding_box()
draw_axi()

    
xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]


ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#vertex types.

f = open('edgesall.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))

f = open('vertextype.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
lll, = np.shape(data);
ppp = (int) (lll/4);
points = np.reshape(data, (ppp,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

for i in range(p):
    edge = np.copy(edges[i]);
    ax.plot(edge[0], edge[1], edge[2], color = 'y', linewidth = .2)



colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(ppp):
    point = points[i]
    c = int (np.floor(point[3]))
    ax.scatter(point[0],point[1], point[2], color = colors[c], linewidth = 2., marker='o')
    
bounding_box()
draw_axi()
    
xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#edgetype from vertextype
#Bounding polygon using edgetypes.

f = open('edgetype.dat', 'r')
data = np.genfromtxt(f, delimiter=',');
f.close()
l, = np.shape(data);
l = (int) (l/7)
edges = np.reshape(data, (l,-1))

f = open('vertextype.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
lll, = np.shape(data);
ppp = (int) (lll/4);
points = np.reshape(data, (ppp,-1))

# %matplotlib notebook

ax = plt.gca(projection="3d")

colors = ['r','b','g','m','c','y','g','k','r'] 
for i in range(l):
    edge = np.copy(edges[i]);
    xa,xb,ya,yb,za,zc, c = edge
    c = (int) (c)
    ax.plot([xa,xb],[ya,yb],[za,zc], colors[c], linewidth = 1.)

draw_axi()

for i in range(ppp):
    point = points[i]
    c = int (np.floor(point[3]))
    ax.scatter(point[0],point[1], point[2], color = colors[c], linewidth = 2., marker='o')
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);


plt.show()     

np.shape(edges)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (17, 7)

# %%
#bounding polygon and projection
f = open('projection.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))

f = open('boundary.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
ll, = np.shape(data);
pp = (int) (ll/6); q = 3 ; r =2;
edgesp = np.reshape(data, (pp,q,r))

f = open('projection2.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
lll, = np.shape(data);
ppp = (int) (lll/6); q = 3 ; r =2;
edgese = np.reshape(data, (ppp,q,r))


# %matplotlib notebook

ax = plt.gca(projection="3d")


for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'g', normalize=False)
for i in range(pp):
    edge = np.copy(edgesp[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'r', normalize=False)
for i in range(ppp):
    edge = np.copy(edgese[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'b', normalize=False)

    
bounding_box()
draw_axi()

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#bounding polygon and projection
# %matplotlib notebook

ax = plt.gca(projection="3d")

f = open('projection.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'g', normalize=False)

f = open('projection2.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'r', normalize=False)
    
f = open('boundary.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'b', normalize=False)

f = open('heightp.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'c', normalize=False, linewidth = 0.5)

f = open('normalp.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'm', normalize=False, linewidth = 0.5)
    
draw_axi()    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#bounding polygon and projection
# %matplotlib notebook

ax = plt.gca(projection="3d")

f = open('projection.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'g', normalize=False)

f = open('projection2.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'r', normalize=False)
    
f = open('boundary.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'b', normalize=False)

f = open('heighte.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'c', normalize=False, linewidth = 0.5)

f = open('normale.dat', 'r') ;data = np.genfromtxt(f, delimiter=','); f.close()
l, = np.shape(data); p = (int) (l/6);
edges = np.reshape(data, (p,3,2))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.quiver(x,y,z, u-x, v-y,w-z, length=1, color = 'm', normalize=False, linewidth = 0.5)


draw_axi()   

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

ax = plt.gca(projection="3d")

f = open('edgesall.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'm')
f = open('vofedges.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))
for i in range(p):
    edge = np.copy(edges[i]);
    x,u = np.copy(edge[0])
    y,v = np.copy(edge[1])
    z,w = np.copy(edge[2])
    ax.plot(edge[0], edge[1], edge[2], color = 'g')


draw_axi()
   
xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = open('projection.dat', 'r')
data = np.genfromtxt(f, delimiter=',')
f.close()
l, = np.shape(data);
p = (int) (l/6); q = 3 ; r =2;
edges = np.reshape(data, (p,q,r))

# %matplotlib notebook

ax = plt.gca(projection="3d")


# ax.add_collection(Poly3DCollection(triangles))

for i in range(p):
    ax.plot(edges[i][0], edges[i][1], edges[i][2])


draw_axi()
    

xlim = [(I_-2)/32.,(I_-1)/32.]
ylim = [(J_-2)/32.,(J_-1)/32.]
zlim = [(K_-2)/32.,(K_-1)/32.]
ax.set_xlim(xlim);ax.set_ylim(ylim);ax.set_zlim(zlim);

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
